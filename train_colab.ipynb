# %% [markdown]
# <a href="https://colab.research.google.com/github/44REAM/newnet/blob/master/train_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd "/content/drive/My Drive/deeplearning"
# !rm -r newnet
# !git clone https://44REAM:cKy77SGgSUvwtCx@github.com/44REAM/newnet.git
import sys

sys.path.append("/content/drive/My Drive/deeplearning/newnet")
# Out:
# /content/drive/My Drive/deeplearning
# Cloning into 'newnet'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 55 (delta 15), reused 47 (delta 10), pack-reused 0
# Unpacking objects: 100% (55/55), done.

# %%
# !pip install wandb
# !pip install python-dotenv
# !pip install yacs

# %%
import numpy as np

from newnet import trainer
from newnet.config import cfg,  set_config

# %%
set_config()
cfg.DATASET.PATH = "/content/drive/My Drive/dataset/radiology/tuberculosis_xray"
cfg.TRAIN.BATCH_SIZE = 16
trainer.train_model()
# Out:
# BATCH: epoch: 7/20 loss: 0.6334698818348072 iter: 267/800 acc: 70.60185185185185
# BATCH: epoch: 7/20 loss: 0.6328412911721638 iter: 268/800 acc: 70.98214285714286
# BATCH: epoch: 7/20 loss: 0.6338213682174683 iter: 269/800 acc: 70.90517241379311
# BATCH: epoch: 7/20 loss: 0.6325961172580719 iter: 270/800 acc: 71.04166666666667
# BATCH: epoch: 7/20 loss: 0.6334286312903127 iter: 271/800 acc: 70.96774193548387
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0a6f19fc2b1a> in <module>()
#       2 cfg.DATASET.PATH = "/content/drive/My Drive/dataset/radiology/tuberculosis_xray"
#       3 cfg.TRAIN.BATCH_SIZE = 16
# ----> 4 trainer.train_model()
#
# /content/drive/My Drive/deeplearning/newnet/newnet/trainer.py in train_model()
#     125     for cur_epoch in range(start_epoch, cfg.OPTIM.MAX_EPOCH):
#     126         # train one epoch
# ...

# %%
import random

# %%
random.sample([1,2,3],1)
# Out:
# [3]
